# %%
import matplotlib.pyplot as plot
import pandas as pd
import numpy as np

co_2018_df = pd.read_csv("CO_2018.csv")
co_2019_df = pd.read_csv("CO_2018.csv")
co_2020_df = pd.read_csv("CO_2018.csv")
no2_2018_df = pd.read_csv("NO2_2018.csv")
no2_2019_df = pd.read_csv("NO2_2019.csv")
no2_2020_df = pd.read_csv("NO2_2020.csv")
pm25_2018_df = pd.read_csv("PM2.5_2018.csv")
pm25_2019_df = pd.read_csv("PM2.5_2019.csv")
pm25_2020_df = pd.read_csv("PM2.5_2020.csv")
# pollutants = ["co","no2","pm25"]
# for pollutant in pollutants:
#     f"{pollutant}_append_df" = f"{pollutant}_2018_df".append([f"{pollutant}_2019_df",f"{pollutant}_2020_df"])
co_append_df = co_2018_df.append([co_2019_df,co_2020_df])
co_append_df = co_append_df.rename(columns={"AQS_PARAMETER_DESC":"POLLUTANT"})
co_append_df["ABBREVIATION"] = "CO"
co

no2_append_df = co_2018_df.append([no2_2019_df,no2_2020_df])
pm25_append_df = pm25_2018_df.append([pm25_2019_df,pm25_2020_df])
co_append_df

# co_append_df["DATE"] = [a.split("/")[0] for a in traffic_df["TIME"]]
# # traffic_df["DATE"] = [(a.split("/")[0]+"/"+a.split("/")[1]) for a in traffic_df["date"]]
# traffic_df["DAY"] = [a.split("/")[1] for a in traffic_df["DATE"]]
# traffic_df["YEAR"] = [a.split("/")[2] for a in traffic_df["DATE"]]
# Out:
#            Date Source    Site ID  POC  Daily Max 8-hour CO Concentration  \
# 0    01/01/2018    AQS  170314201    1                                0.5
# 1    01/02/2018    AQS  170314201    1                                0.4
# 2    01/03/2018    AQS  170314201    1                                0.6
# 3    01/04/2018    AQS  170314201    1                                0.6
# 4    01/05/2018    AQS  170314201    1                                0.7
# ..          ...    ...        ...  ...                                ...
# 340  12/27/2018    AQS  170314201    1                                0.2
# 341  12/28/2018    AQS  170314201    1                                0.2
# 342  12/29/2018    AQS  170314201    1                                0.2
# 343  12/30/2018    AQS  170314201    1                                0.2
# 344  12/31/2018    AQS  170314201    1                                0.3
#
#     UNITS  DAILY_AQI_VALUE               Site Name  DAILY_OBS_COUNT  \
# ...

# %%
no2_append_df

# %%
pm25_append_df
